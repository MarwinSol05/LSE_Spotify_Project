# %% [markdown]
# ># 2. Data Acquisition: Audio Features Data

# %% [markdown]
# Our group leveraged the Spotify API to gather information on music tracks. Data Acquisition was performed in two separate notebooks given API rate limits. This notebook is meant to be run second, to gather all audio features of the tracks that we have chosen to include in our analysis. As described previously, the first step of leveraging the Spotify API is the client credentials flow performed again below and leveraging the same client keys.
#
# PLEASE NOTE: If re-running this file, data collection via the API can take some amount of time. If pausing and re-running the same blocks of code multiple times, care must be taken to allow for a brief pause to avoid exceeding rate limits. Additionally, please note that the command to create a CSV file from the API calls below has been commented out to prevent writing over the files created by our group. Given that API output can differ by day, we wanted to ensure that our analysis produced consistent results during the marking phase of this project.

# %%
# library load & key load
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import pandas as pd
import time
import timeit

with open('keys_personal.json') as f:
    keys = json.load(f)
cid = keys['spotify']['client_id']
secret = keys['spotify']['client_secret']

# %%
# client credentials flow
spotify = spotipy.Spotify(client_credentials_manager = 
                          SpotifyClientCredentials(client_id=cid, client_secret=secret))

# %%
spotify

# %% [markdown]
# ________________

# %% [markdown]
# ### Gathering features for all gathered tracks:
#
# Note, [this](https://towardsdatascience.com/spotify-data-project-part-1-from-data-retrieval-to-first-insights-f5f819f8e1c3) article was used as a reference point for the batching process leveraged below though code and processes were altered for our use-case.

# %%
df_tracks = pd.read_csv('spotify_tracks.csv')
df_tracks.head()
# Out:
#    year market   artist_name               artist_id  \
# 0  2022     US           SZA  7tYKF4w9nC0nq9CsPZTHyP
# 1  2022     US  Metro Boomin  0iEtIxbK0KxaSlF7G42ZOp
# 2  2022     US         Drake  3TVXtAsR1Inumwj472S9r4
# 3  2022     US  Metro Boomin  0iEtIxbK0KxaSlF7G42ZOp
# 4  2022     US  Lil Uzi Vert  4O15NlyKLIASxsJ0PrXPfz
#
#                                           track_name                track_id  \
# 0                                          Kill Bill  3OHfY25tqY28d16oZczHc8
# 1             Creepin' (with The Weeknd & 21 Savage)  2dHHgzDwk4BJdRwy9uXhTO
# 2                                          Rich Flex  1bDbXMyjaUIooNwFE9wn0N
# 3  Superhero (Heroes & Villains) [with Future & C...  0vjeOZ3Ft5jvAi9SBFJm1j
# 4                                    Just Wanna Rock  4FyesJzVpA39hbYvcseO2d
#
#    popularity                                       artist_genre
# 0          93                                     ['pop', 'r&b']
# 1          94                                            ['rap']
# 2          91  ['canadian hip hop', 'canadian pop', 'hip hop'...
# 3          88                                            ['rap']
# 4          88       ['melodic rap', 'philly rap', 'rap', 'trap']

# %%
df_tracks.shape
# Out:
# (9394, 8)

# %%
features = []
size = 100
no_feats = 0

start = timeit.default_timer()

for step in range(0,len(df_tracks['track_id']),size):
    
    batch = df_tracks['track_id'][step:step+size]
    feat_results = spotify.audio_features(batch)
    
    for index, data in enumerate(feat_results):
        if data == None:
            no_feats += 1
        else:
            features.append(data)

stop = timeit.default_timer()
print ('Time to run (in seconds): ', stop - start)
# Out:
# Time to run (in seconds):  9.090163542000028

# %%
print('Number of tracks where no features were available: ',no_feats)
print('Number of elements in the feature list: ', len(features))
# Out:
# Number of tracks where no features were available:  14
# Number of elements in the feature list:  9380

# %%
# turning into dataframe
df_features = pd.DataFrame.from_dict(features,orient='columns')
df_features.shape
# Out:
# (9380, 18)

# %%
df_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.644   0.728    8    -5.750     1       0.0351        0.0543
# 1         0.715   0.620    1    -6.005     0       0.0484        0.4170
# 2         0.561   0.520   11    -9.342     0       0.2440        0.0503
# 3         0.526   0.606    5    -5.300     0       0.2590        0.1520
# 4         0.486   0.545   11    -7.924     1       0.0336        0.0652
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.169000    0.1610   0.4300   88.993  audio_features
# 1          0.000000    0.0822   0.1720   97.950  audio_features
# 2          0.000002    0.3550   0.4240  153.150  audio_features
# 3          0.000002    0.1940   0.4920  116.622  audio_features
# 4          0.004740    0.0642   0.0385  150.187  audio_features
#
#                        id                                   uri  \
# 0  3OHfY25tqY28d16oZczHc8  spotify:track:3OHfY25tqY28d16oZczHc8
# 1  2dHHgzDwk4BJdRwy9uXhTO  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
# 2  1bDbXMyjaUIooNwFE9wn0N  spotify:track:1bDbXMyjaUIooNwFE9wn0N
# 3  0vjeOZ3Ft5jvAi9SBFJm1j  spotify:track:0vjeOZ3Ft5jvAi9SBFJm1j
# 4  4FyesJzVpA39hbYvcseO2d  spotify:track:4FyesJzVpA39hbYvcseO2d
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3OHfY25tqY28...
# 1  https://api.spotify.com/v1/tracks/2dHHgzDwk4BJ...
# 2  https://api.spotify.com/v1/tracks/1bDbXMyjaUIo...
# 3  https://api.spotify.com/v1/tracks/0vjeOZ3Ft5jv...
# 4  https://api.spotify.com/v1/tracks/4FyesJzVpA39...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3OHf...       153947
# 1  https://api.spotify.com/v1/audio-analysis/2dHH...       221520
# 2  https://api.spotify.com/v1/audio-analysis/1bDb...       239360
# 3  https://api.spotify.com/v1/audio-analysis/0vje...       182667
# 4  https://api.spotify.com/v1/audio-analysis/4Fye...       123891
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               4
# 4               4

# %%
# renaming ID column to track ID
df_features.rename(columns={'id': 'track_id'}, inplace=True)

# %%
df_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.644   0.728    8    -5.750     1       0.0351        0.0543
# 1         0.715   0.620    1    -6.005     0       0.0484        0.4170
# 2         0.561   0.520   11    -9.342     0       0.2440        0.0503
# 3         0.526   0.606    5    -5.300     0       0.2590        0.1520
# 4         0.486   0.545   11    -7.924     1       0.0336        0.0652
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.169000    0.1610   0.4300   88.993  audio_features
# 1          0.000000    0.0822   0.1720   97.950  audio_features
# 2          0.000002    0.3550   0.4240  153.150  audio_features
# 3          0.000002    0.1940   0.4920  116.622  audio_features
# 4          0.004740    0.0642   0.0385  150.187  audio_features
#
#                  track_id                                   uri  \
# 0  3OHfY25tqY28d16oZczHc8  spotify:track:3OHfY25tqY28d16oZczHc8
# 1  2dHHgzDwk4BJdRwy9uXhTO  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
# 2  1bDbXMyjaUIooNwFE9wn0N  spotify:track:1bDbXMyjaUIooNwFE9wn0N
# 3  0vjeOZ3Ft5jvAi9SBFJm1j  spotify:track:0vjeOZ3Ft5jvAi9SBFJm1j
# 4  4FyesJzVpA39hbYvcseO2d  spotify:track:4FyesJzVpA39hbYvcseO2d
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3OHfY25tqY28...
# 1  https://api.spotify.com/v1/tracks/2dHHgzDwk4BJ...
# 2  https://api.spotify.com/v1/tracks/1bDbXMyjaUIo...
# 3  https://api.spotify.com/v1/tracks/0vjeOZ3Ft5jv...
# 4  https://api.spotify.com/v1/tracks/4FyesJzVpA39...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3OHf...       153947
# 1  https://api.spotify.com/v1/audio-analysis/2dHH...       221520
# 2  https://api.spotify.com/v1/audio-analysis/1bDb...       239360
# 3  https://api.spotify.com/v1/audio-analysis/0vje...       182667
# 4  https://api.spotify.com/v1/audio-analysis/4Fye...       123891
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               4
# 4               4

# %%
# checking for duplicates
grouped = df_features.groupby(['track_id'], as_index=True).size()
grouped[grouped > 1]
# Out:
# track_id
# 00Blm7zeNqgYLPtW6zg8cj    4
# 00NAQYOP4AmWR549nnYJZu    2
# 017PF4Q3l4DBUiWoXk4OWT    2
# 01JPQ87UHeGysPVwTqMJHK    2
# 01K4zKU104LyJ8gMb7227B    2
#                          ..
# 7ytR5pFWmSjzHJIeQkgog4    3
# 7zFXmv6vqI4qOt4yGf3jYZ    3
# 7zLYKWcXnYeHHWidalz7rj    3
# 7zwn1eykZtZ5LODrf7c0tS    3
# 7zxRMhXxJMQCeDDg0rKAVo    2
# Length: 1669, dtype: int64

# %%
# example of duplicates - seems like all feature values are the same
df_features[df_features['track_id'] == '00Blm7zeNqgYLPtW6zg8cj']
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1243         0.687   0.781    1    -4.806     1        0.053        0.0361
# 1583         0.687   0.781    1    -4.806     1        0.053        0.0361
# 1970         0.687   0.781    1    -4.806     1        0.053        0.0361
# 2264         0.687   0.781    1    -4.806     1        0.053        0.0361
#
#       instrumentalness  liveness  valence   tempo            type  \
# 1243               0.0    0.0755    0.688  97.014  audio_features
# 1583               0.0    0.0755    0.688  97.014  audio_features
# 1970               0.0    0.0755    0.688  97.014  audio_features
# 2264               0.0    0.0755    0.688  97.014  audio_features
#
#                     track_id                                   uri  \
# 1243  00Blm7zeNqgYLPtW6zg8cj  spotify:track:00Blm7zeNqgYLPtW6zg8cj
# 1583  00Blm7zeNqgYLPtW6zg8cj  spotify:track:00Blm7zeNqgYLPtW6zg8cj
# 1970  00Blm7zeNqgYLPtW6zg8cj  spotify:track:00Blm7zeNqgYLPtW6zg8cj
# 2264  00Blm7zeNqgYLPtW6zg8cj  spotify:track:00Blm7zeNqgYLPtW6zg8cj
#
#                                              track_href  \
# 1243  https://api.spotify.com/v1/tracks/00Blm7zeNqgY...
# 1583  https://api.spotify.com/v1/tracks/00Blm7zeNqgY...
# 1970  https://api.spotify.com/v1/tracks/00Blm7zeNqgY...
# 2264  https://api.spotify.com/v1/tracks/00Blm7zeNqgY...
#
#                                            analysis_url  duration_ms  \
# 1243  https://api.spotify.com/v1/audio-analysis/00Bl...       193507
# 1583  https://api.spotify.com/v1/audio-analysis/00Bl...       193507
# 1970  https://api.spotify.com/v1/audio-analysis/00Bl...       193507
# 2264  https://api.spotify.com/v1/audio-analysis/00Bl...       193507
#
#       time_signature
# 1243               4
# 1583               4
# 1970               4
# 2264               4

# %%
# dropping duplicates to avoid merge complications and since values are all same
df_features.drop_duplicates(subset=['track_id'], inplace=True)

# %%
df_features.shape
# Out:
# (6563, 18)

# %%
df = df_tracks.merge(df_features, on = 'track_id', how = 'inner')

# %%
df.shape
# Out:
# (9380, 25)

# %%
df.head()
# Out:
#    year market   artist_name               artist_id  \
# 0  2022     US           SZA  7tYKF4w9nC0nq9CsPZTHyP
# 1  2022     IN           SZA  7tYKF4w9nC0nq9CsPZTHyP
# 2  2022     NL           SZA  7tYKF4w9nC0nq9CsPZTHyP
# 3  2022     US  Metro Boomin  0iEtIxbK0KxaSlF7G42ZOp
# 4  2022     GB  Metro Boomin  0iEtIxbK0KxaSlF7G42ZOp
#
#                                track_name                track_id  popularity  \
# 0                               Kill Bill  3OHfY25tqY28d16oZczHc8          93
# 1                               Kill Bill  3OHfY25tqY28d16oZczHc8          93
# 2                               Kill Bill  3OHfY25tqY28d16oZczHc8          93
# 3  Creepin' (with The Weeknd & 21 Savage)  2dHHgzDwk4BJdRwy9uXhTO          94
# 4  Creepin' (with The Weeknd & 21 Savage)  2dHHgzDwk4BJdRwy9uXhTO          94
#
#      artist_genre  danceability  energy  ...  instrumentalness  liveness  \
# 0  ['pop', 'r&b']         0.644   0.728  ...             0.169    0.1610
# 1  ['pop', 'r&b']         0.644   0.728  ...             0.169    0.1610
# 2  ['pop', 'r&b']         0.644   0.728  ...             0.169    0.1610
# 3         ['rap']         0.715   0.620  ...             0.000    0.0822
# 4         ['rap']         0.715   0.620  ...             0.000    0.0822
#
#    valence   tempo            type                                   uri  \
# 0    0.430  88.993  audio_features  spotify:track:3OHfY25tqY28d16oZczHc8
# 1    0.430  88.993  audio_features  spotify:track:3OHfY25tqY28d16oZczHc8
# 2    0.430  88.993  audio_features  spotify:track:3OHfY25tqY28d16oZczHc8
# 3    0.172  97.950  audio_features  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
# 4    0.172  97.950  audio_features  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3OHfY25tqY28...
# 1  https://api.spotify.com/v1/tracks/3OHfY25tqY28...
# 2  https://api.spotify.com/v1/tracks/3OHfY25tqY28...
# 3  https://api.spotify.com/v1/tracks/2dHHgzDwk4BJ...
# 4  https://api.spotify.com/v1/tracks/2dHHgzDwk4BJ...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3OHf...       153947
# 1  https://api.spotify.com/v1/audio-analysis/3OHf...       153947
# 2  https://api.spotify.com/v1/audio-analysis/3OHf...       153947
# 3  https://api.spotify.com/v1/audio-analysis/2dHH...       221520
# 4  https://api.spotify.com/v1/audio-analysis/2dHH...       221520
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 25 columns]

# %% [markdown]
# PLEASE NOTE: If re-running this file, do not re-run the line below to avoid overwriting the files created by our group which could impact the dataset used in the report.

# %%
#df.to_csv('spotify_tracks_feats.csv', index = False)
